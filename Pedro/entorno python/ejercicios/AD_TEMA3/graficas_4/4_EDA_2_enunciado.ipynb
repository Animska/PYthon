# %% [markdown]
# # Práctica: Análisis Exploratorio de Datos (EDA)
#
# En esta práctica trabajaremos con un dataset que contiene información sobre el rendimiento académico de estudiantes en diferentes asignaturas.
#
# En este punto ya se debe empezar a dominar Matplotlib o Seaborn, por lo que se pide que se intente hacer sin IA en primer lugar para ejercitar la memoria y la búsqueda en la documentación...
#
# El objetivo es realizar un Análisis Exploratorio de Datos (EDA) aplicando:
#
# - Estadística descriptiva
# - Visualización con Matplotlib y Seaborn
# - Análisis de distribuciones
# - Correlaciones
# - Comparación entre grupos
# - Detección de valores atípicos
#
# No se trata solo de generar gráficos, sino de **interpretar lo que los datos nos están diciendo**.
#
# __Se deben responder a las preguntas en las celdas markdown__
#
# Si utilizas funciones y parámetros no vistos en los apuntes haz un listado en una celda al final del notebook documentando para que sirve.

# %% [markdown]
# # PARTE 1 - Carga y exploración inicial
#
# En 3 celdas de código:
#
# 1. Carga el dataset y muestra las primeras filas.
# 2. Muestra y Analiza:
#    - Número de filas y columnas.
#    - Tipos de variables.
#    - Valores nulos y duplicados
# 3. Almacena en 2 listas las variables categóricas y las variables numéricas
#
#
# ### Responde a las preguntas:
#
# - ¿Cuáles son las variables numéricas?
# - ¿Cuáles son las categóricas?
# - ¿Existen valores nulos?
# - ¿Qué variable crees que será la más interesante de analizar?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("exams.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
print(f"Tamaño del dataset: filas={df.shape[0]}, columnas={df.shape[1]}")
print("\nEstadísticas de las variables numéricas del Data set")
display(df.describe())

print("\nNulos por columna:")
display(df.isnull().sum())

print("\nDuplicados:", df.duplicated().sum())
# Out:
# Tamaño del dataset: filas=1000, columnas=8
#
# Estadísticas de las variables numéricas del Data set
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.396000      69.002000      67.738000
# std      15.402871      14.737272      15.600985
# min      13.000000      27.000000      23.000000
# 25%      56.000000      60.000000      58.000000
# 50%      66.500000      70.000000      68.000000
# 75%      77.000000      79.000000      79.000000
# max     100.000000     100.000000     100.000000
# Nulos por columna:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64
# Duplicados: 1

# %%
# Puede ser interesante almacenar en sendas listas los tipos de variables para tratarlas automáticamente
# Variables numércias
num_cols = ["math score", "reading score", "writing score"]
# Variables discretas/categóricas
cat_cols = [c for c in df.columns if c not in num_cols]
print("Categóricas:", cat_cols)
print("Numéricas:", num_cols)
# Out:
# Categóricas: ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']
# Numéricas: ['math score', 'reading score', 'writing score']

# %% [markdown]
# # PARTE 2 — Análisis Variables numéricas

# %% [markdown]
# ## 2.1. Análisis de distribuciones
#
# Para cada una de las tres variables numéricas (en un figure de 3x1):
#
# 1. Representa un histograma con Seaborn con la línea que suaviza la distribución.
# 2. Añade líneas verticales indicando:
#    - Media
#    - Mediana
#
#
# ### Responde a las preguntas:
# - ¿Son simétricas? ¿cuál lo es más y cuál menos?
# - ¿Hay sesgo a la derecha o izquierda?
# - ¿Media y mediana coinciden?
# - ¿Cuál presenta mayor dispersión?
# - ¿Alguna parece aproximarse a una distribución normal?

# %%
# Configuración del tema y estilo
plt.rcParams["figure.dpi"] = 120
plt.rcParams["axes.titleweight"] = "bold"
plt.rcParams["axes.grid"] = True
sns.set_theme(style="whitegrid", context="notebook")  

fig, axes = plt.subplots(1, 3, figsize=(16, 4), sharey=True)

# Definimos un umbral de tolerancia para decidir si hay sesgo a la izquierda o derecha en función del std
# Ejemplo: si la diferencia es menor al 1% del rango o de la desviación estándar
umbral_tolerancia = 0.05

# En lugar de indexar manualmente, lo hacemos en un for
for ax, col in zip(axes, num_cols):
    # Calculamos valores media y mediana
    mean_val = df[col].mean()
    median_val = df[col].median()
    # Usamos la desviación estándar para relativizar la diferencia mediana - media y analizar el sesgo
    std_val = df[col].std() 
    
    # Pintamos el histograma con kde
    sns.histplot(df[col], bins=20, kde=True, ax=ax)
    # Pintamos las líneas verticales de media y mediana
    ax.axvline(mean_val, linestyle="--", linewidth=2, label=f"Media: {mean_val:.2f}")
    ax.axvline(median_val, linestyle="-", linewidth=2, label=f"Mediana: {median_val:.2f}")
    # Indicamos títulos y nombres de ejes
    ax.set_title(f"Distribución: {col}")
    ax.set_xlabel("Puntuación")
    ax.set_ylabel("Frecuencia")

    # Lógica de aproximación:
    # Calculamos la diferencia absoluta relativa a la dispersión de los datos
    diferencia = mean_val - median_val
    if abs(diferencia) < (std_val * umbral_tolerancia):
        bias = "Simétrica (Media ≈ Mediana)"
        color_texto = "blue"
    elif diferencia > 0:
        bias = "Sesgo a la derecha (Media > Mediana)"
        color_texto = "darkred"
    else:
        bias = "Sesgo a la izquierda (Media < Mediana)"
        color_texto = "darkgreen"

    # Pintamos el texto en la esquina superiro izquierda
    ax.text(0.02, 0.95, bias, transform=ax.transAxes, va="top", fontsize=9)
    # Pintamos leyenda
    ax.legend()
    
# Título global del figure
plt.suptitle("Histogramas de notas con Media y Mediana", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.2 Medidas de dispersión
#
# Calcula para cada asignatura:
#
# - Min
# - Max
# - Media
# - Mediana (Q2)
# - Q1
# - Q3
# - Desviación estándar
# - Rango intercuartílico (IQR)
#
# Redondea valores a 2 decimales máximo.
# Mételos en un Dataframe y muestra el resultado.
#
#
# ### Responde a las preguntas:
# - ¿En qué asignatura hay mayor variabilidad?
# - ¿En cuál la media es menos representativa?

# %%
summary = pd.DataFrame({
    "media": df[num_cols].mean(),
    "mediana": df[num_cols].median(),
    "std": df[num_cols].std(),
    "min": df[num_cols].min(),
    "max": df[num_cols].max(),
    "Q1": df[num_cols].quantile(0.25),
    "Q3": df[num_cols].quantile(0.75),
    "IQR": df[num_cols].quantile(0.75) - df[num_cols].quantile(0.25),
}).round(2)

summary
# Out:
#                media  mediana    std  min  max    Q1    Q3   IQR
# math score     66.40     66.5  15.40   13  100  56.0  77.0  21.0
# reading score  69.00     70.0  14.74   27  100  60.0  79.0  19.0
# writing score  67.74     68.0  15.60   23  100  58.0  79.0  21.0

# %% [markdown]
# # PARTE 3 - Variables categóricas

# %% [markdown]
# ## 3.1. Variables categóricas
#
# Representa en un figure de 3 columnas todas las variables categóricas:
#
# 1. Cada gráfica es un gráfico de barras. Cada barra es una categoría dentro de la variable. La altura es el número de individuos dentro de esa categoría. Puedes usar countplot de SEaborn.
# 2. Calcula y muestra la moda de cada variable.
# 3. En 2 celdas adicionales de código, muestra en gráficos de tarta la distribución de parental level of education y race/ethinicty

# %%
import math
# Calculamos cuántas filas necesitamos si tenemos 3 columnas
cols = 3  # 3 columnas para el figure
rows = math.ceil(len(cat_cols) / cols) # Calculamos cuántas filas

fig, axes = plt.subplots(rows, cols, figsize=(13, 8))
# Aplanamos la matriz de axes
axes = axes.flatten()
# Recorremos los subplots para pintar cada gráfica. col es el nombre de cada variable en la lista cat_cols
for ax, col in zip(axes, cat_cols):
    # Obtenemos de cada columna el contador de valores de cada categoría, que lo devuelve de mayor a menor
    # Con index nos quedamos solamente con etiquetas. 
    # Así tenemos las etiquetas ordenadas de mayor a menor altura de barra
    order = df[col].value_counts().index
    # Este parámetro se pasa a order de Seaborn.coutnplot para que las barras se muestren de menor a mayor
    sns.countplot(data=df, x=col, order=order, ax=ax)

    # Pintamos información de cada subplot
    ax.set_title(f"Frecuencia: {col}")
    ax.set_xlabel("")
    ax.set_ylabel("Nº estudiantes")
    # Rotamos las etiquetas
    ax.tick_params(axis="x", rotation=60)

    # Obtenemos el valor máximo actual del eje Y y lo multiplicamos por 1.15 para que la barra más alta no se pegue arriba
    ax.set_ylim(0, ax.get_ylim()[1] * 1.15)
    # Pintamos el valor encima de cada barra
    ax.bar_label(ax.containers[0])

# Eliminar ejes vacíos (el último subplot)
for i in range(len(cat_cols), len(axes)):
    fig.delaxes(axes[i])

# Título global
plt.suptitle("Distribución de todas las variables categóricas", y=1.02)
plt.tight_layout()
plt.show()

# Modas
for col in cat_cols:
    print(f"{col} = {df[col].mode()[0]}")
# Out:
# gender = male
# race/ethnicity = group C
# parental level of education = some college
# lunch = standard
# test preparation course = none

# %%
# Primer diagrama de tartas
# Columna
col = "parental level of education"
# Obtenemos los totales de cada valor
counts = df[col].value_counts()
# Figure
plt.figure(figsize=(6, 6))
# Jugamos con el ángulo (startangle) para que se vea incrementalmente en orden de las agujas del reloj
plt.pie(x=counts.values, labels=counts.index, autopct="%1.1f%%", startangle=90, pctdistance=0.8)
plt.title("Distribución: Parental Level of Education")
plt.tight_layout()
plt.show()

# %%
# 2º diagrama de tartas
col = "race/ethnicity"
counts = df[col].value_counts()
# Obtenemos los totales de cada valor
counts = df[col].value_counts()
# Figure
plt.figure(figsize=(6, 6))
# Jugamos con el ángulo (startangle) para que se vea incrementalmente en orden de las agujas del reloj
plt.pie(x=counts.values, labels=counts.index, autopct="%1.1f%%", startangle=90, pctdistance=0.8)
plt.title("Distribución: Parental Level of Education")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Responde a las preguntas para cada variable:
# - ¿Qué categoría es dominante en cada variable?
# - ¿La distribución de cada variable es equilibrada o claramente descompensada?

# %% [markdown]
# # PARTE 4- Comparación entre grupos

# %% [markdown]
# ## 4.1 Comparación de notas según el sexo
#
# Analiza si existen diferencias en las notas de las 3 asignaturas según el género.
#
# 1. Representa un boxplot para cada asignatura. En cada asignatura debe haber una caja para cada género (male, female).
#
# ### Analiza y responde:
#    - Diferencias en mediana
#    - Diferencias en dispersión
#    - Presencia de outliers

# %%
# Un figure de 3 gráficas en fila
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
# Recorremos la lista de subplots junto a los nombres de las columnas
for ax, col in zip(axes, num_cols):
    # Cada subplot es una boxplot. El eje x es el género, así pintará 2 boxs una por género.
    # El eje y de cada gráfica es el nombre de la variable numérica a mostrar
    sns.boxplot(data=df, x="gender", y=col, ax=ax)
    # Pintamos la información de cada una
    ax.set_title(f"{col} por género")
    ax.set_xlabel("")
    ax.set_ylabel("Puntuación")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.2. Comparación de notas según tipo de lunch
#
# En este apartado analizaremos si existe alguna relación entre el tipo de comida que recibe el estudiante (`lunch`) y su rendimiento académico.
#
# Para ello:
#
# 1. Representa un diagrama de barras (`barplot`) para cada asignatura:
#    - Matemáticas
#    - Lectura
#    - Escritura
#
# 2. En cada gráfico:
#    - El eje X debe representar el tipo de lunch.
#    - El eje Y debe representar la **media de la nota**.
#
# ⚠ Importante:
# El gráfico de barras en Seaborn no muestra frecuencias, sino que calcula automáticamente la media de la variable numérica para cada categoría y añade un intervalo de confianza.
#
# ### Responde a las preguntas:
#    - ¿Existen diferencias claras entre los grupos?
#    - ¿Las medias son significativamente distintas (según el IC)?
#    - ¿Qué hipótesis podrías plantear sobre la relación entre alimentación y rendimiento?

# %%
# Son 3 variables a mostrar, hacemos un figure con 3 subplots en línea
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
# Recorremos los subplots y las columnas numéricas
for ax, col in zip(axes, num_cols):
    # Cada figure es un batplot. El eje x es la variable Lunch. El eje y es cada variable numérica
    # Seaborn en barplot calcula la media de nota para cada tipo de lunch y esta será la altura de la barra
    # La media puede ser engañosa (si mucha o poca dispersión)
    # batplot también pinta un rango de error. errorbar puede ser 'ci' (intervalo de confianza, por defecto), 'sd' (desviación estándar) o None
    # con ci, si barra pequeña-> poca dispersión, si barra grande-> mucha dispersión. 
    sns.barplot(data=df, x="lunch", y=col, ax=ax, errorbar="ci")
    ax.set_title(f"Media de {col} por tipo de lunch")
    ax.set_xlabel("")
    ax.set_ylabel("Media (con IC)")
    ax.tick_params(axis="x", rotation=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.3. Comparación de notas según el curso de preparación
#
# En este apartado analizaremos si haber completado el curso de preparación (`test preparation course`) influye en el rendimiento académico.
#
# Para ello:
#
# 1. Representa un **boxplot** para cada asignatura:
#    - Matemáticas
#    - Lectura
#    - Escritura
#
# 2. En cada gráfico:
#    - El eje X debe mostrar las categorías del curso de preparación (completed / none).
#    - El eje Y debe representar la puntuación obtenida.
#    - Se debe visualizar la mediana, el rango intercuartílico (IQR) y los posibles valores atípicos.
#
# 3. Añade además la **media de cada grupo como un punto rojo** sobre el boxplot para comparar visualmente media y mediana.
#
# ### Responde a las preguntas:
#    - ¿Las medianas son mayores en el grupo que completó el curso?
#    - ¿Existen diferencias en la dispersión de las notas?
#    - ¿Hay más valores atípicos en algún grupo?
#    - ¿La media y la mediana son similares o hay indicios de sesgo?

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 4))

for ax, col in zip(axes, num_cols):
    # Cada variable numérica es un boxplot, el eje x es si hubo preparación o no (solo exiten 2 categorías) -> 2 boxs por gráfica
    sns.boxplot(data=df, x="test preparation course", y=col, ax=ax)

    # Añadimos la media como punto rojo y así podemos comparar con la mediana (línea media del box)
    # Calculamos la media de la variable numérica agrupando por test preparation
    means = df.groupby("test preparation course")[col].mean()
    # Las pintamos en el box con un scatter
    for i, mean in enumerate(means):
        ax.scatter(i, mean, color="red", s=60, zorder=5, label="Media" if i == 0 else "")

    # Información de cada gráfica
    ax.set_title(f"{col} por curso de preparación")
    ax.set_xlabel("")
    ax.set_ylabel("Puntuación")
    ax.tick_params(axis="x", rotation=10)

# Pintamos la leyenda. Como es la misma para todas, con hacerlo en el primer subplot basta
axes[0].legend()
# Título global dle figure
plt.suptitle("Comparación de notas según curso de preparación", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# # PARTE 5 — Relaciones entre variables numéricas

# %% [markdown]
# ## 5.1. Relación entre variables numéricas
#
# 1. Representa un scatterplot de SEaborn entre:
#    - Math y Reading
#    - Reading y Writing
#    - Math y Writing
# 2. Añade línea de regresión con Seaborn.
# 3. Calcula la correlación de Pearson y que se vea en la legenda.
#
# ### Responde a las preguntas
# - ¿Es fuerte?¿Es lineal? ¿es positiva o negativa?
# - ¿Qué par de variables está más correlacionado?
# - ¿Tiene sentido pedagógico esta relación?

# %%
# Pares de variables a mostrar
pairs = [("math score", "reading score"), ("reading score", "writing score"), ("math score", "writing score")]
# Creamos un figure de 3 gráficas en línea
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
# Recorremos los figures y los pares de variables para pinar cada gráfica
for ax, (x, y) in zip(axes, pairs):
    # Usamos regplot ya que es un scatter con línea de regresión.
    sns.regplot(data=df, 
                x=x, # variable eje x
                y=y, # variable eje y 
                ax=ax, 
                scatter_kws={"color": "skyblue", "alpha": 0.5}, # Color y transparencia de los puntos
                line_kws={"color": "red", "lw": 2}              # Color y grosor (lw) de la recta de regresión
               )
    # Calculamos la regresión del par x y
    r = df[[x, y]].corr(method="pearson").iloc[0, 1]
    # Pintamos leyenda
    ax.set_title(f"{x} vs {y}")
    # Pintamos el texto con el valor de regresión de cada gráfica
    ax.text(0.02, 0.95, f"Pearson r = {r:.3f}", transform=ax.transAxes, va="top")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5.2. Matriz de correlación
#
# Representa la matriz de correlación mediante un heatmap.

# %%
corr = df[num_cols].corr(method="pearson")

plt.figure(figsize=(5, 4))
sns.heatmap(corr, annot=True, vmin=-1, vmax=1, square=True)
plt.title("Matriz de correlación (Pearson)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # PARTE 6 — Percentiles y detección de outliers

# %% [markdown]
# ## 6.1. Percentiles
#
# Calcula el percentil 90 en matemáticas y responde.
# - ¿Qué nota corresponde?
# - ¿Cuántos alumnos lo superan?

# %%
p90 = df["math score"].quantile(0.90) # 0.9 es el percentil 90%
n_over = (df["math score"] > p90).sum() # Sumamos los que dan True a la comparación para saber cuántos están por encima del p 90%
n_total = len(df) # Filas totales
print(f"Percentil 90 (math score): {p90:.2f}")
print(f"Estudiantes por encima del p90: {n_over} de {n_total} ({(n_over/n_total)*100:.1f}%)")
# Out:
# Percentil 90 (math score): 86.00
# Estudiantes por encima del p90: 95 de 1000 (9.5%)

# %% [markdown]
# ## 6.2 Outliers con IQR
# Detecta manualmente los valores atípicos en matemáticas utilizando la regla (la misma que usa Boxplot para marcar los valores fuera de los bigotes):
#
# Q1 − 1.5×IQR
# Q3 + 1.5×IQR
#
# + Haz el calculo para saber que valor es el límite de cada outliers.
# + Muestra cuántos outliers hay por encima y por debajo
# + Filtra el DF para mostrar las filas que son los outliers de esta asignatura.

# %%
col = "math score"
# Calculamos el primer cuartil (p25) y el tercer cuartil (p75)
q1 = df[col].quantile(0.25)
q3 = df[col].quantile(0.75)
# Q3 - Q1 es el rango intercuantílico IQR
iqr = q3 - q1

# Buscamos los límites de los bigotes 
low = q1 - 1.5 * iqr # Q1 - 1.5IQR
high = q3 + 1.5 * iqr # Q3 + 1.5IQR
# Los atípicos son los que están por debajo de "low" y por encima de "high"
outliers = df[(df[col] < low) | (df[col] > high)]
# Imprimimos valores
print(f"{col}: Q1={q1:.2f}, Q3={q3:.2f}, IQR={iqr:.2f}")
print(f"Límites outliers: [{low:.2f}, {high:.2f}]")
print(f"Nº outliers detectados: {len(outliers)}")
outliers.head()
# Out:
# math score: Q1=56.00, Q3=77.00, IQR=21.00
# Límites outliers: [24.50, 108.50]
# Nº outliers detectados: 3
#      gender race/ethnicity parental level of education         lunch  \
# 18   female        group C          associate's degree  free/reduced
# 392  female        group C                some college  free/reduced
# 832  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 18                     none          23             44             44
# 392                    none          13             29             23
# 832                    none          13             36             37

# %%
#Vamos a verificar con un boxpot
sns.boxplot(df, y='math score')
plt.show()
# Salen 2 puntos porque en el punto 13 coinciden 2 notas

# %% [markdown]
# # PARTE 7 - Conclusiones finales

# %% [markdown]
# ## Conclusiones
#
# Redacta un pequeño informe respondiendo:
#
# - ¿Qué asignatura presenta mayor dificultad?
# - ¿Existe diferencia real entre géneros?
# - ¿Qué variable influye más en el rendimiento?
# - ¿Los datos siguen una distribución normal?
# - ¿Qué conclusiones educativas podrían extraerse?

# %% [markdown]
# Las tres notas suelen estar positivamente correlacionadas, lo que indica consistencia: quien obtiene buen rendimiento en una asignatura tiende a hacerlo también en las otras.
#
#
# El curso de preparación suele asociarse con mejores medianas/medias.
#
#
# El tipo de lunch puede reflejar diferencias socioeconómicas y aparece como un factor con diferencias en medias.
#
#
# Las distribuciones son generalmente unimodales y relativamente simétricas.
#
#
# Los outliers detectados con IQR suelen ser pocos.
